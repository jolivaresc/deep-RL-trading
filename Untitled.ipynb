# %%
import os
import pickle
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
DATA_PATH = "data"

# %%
time_series = pickle.load(open("data/PairSamplerDB/randjump_100,1(10, 30)[]_A/db.pickle",'rb'))

# %%
type(time_series)
# Out:
# list

# %%
time_series = np.array(time_series)

# %%
time_series[0][0][:2]
# Out:
# array([[ 170.23711624,  174.30894536],
#        [ 170.23711624,  171.70221958]])

# %%
# y = np.random.normal(2*time_series[0][0]+2,20)

# %%
# new = np.hstack(time_series,y)

# %%
plt.plot(time_series[0][0],)

# %%
plt.plot(time_series[1][0])

# %%
def model(env, learning_rate, fld_load):
    print_t = False
    exploration_init = 1.
    
    m = 16
